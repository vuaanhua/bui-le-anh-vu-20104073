# %% [markdown]
# <a href="https://colab.research.google.com/github/vuaanhua/bui-le-anh-vu-20104073/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Multi-task Cascaded Convolutional Networks

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 5.3 MB/s
# ...

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN

# %%
url='/content/AVU.jpg'
pixel=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixel)
# Out:
# ...
# 4/4 [==============================] - 0s 42ms/step

# %%
for face in faces:
  print(face)
# Out:
# {'box': [158, 91, 16, 17], 'confidence': 0.9999805092811584, 'keypoints': {'left_eye': (164, 97), 'right_eye': (171, 98), 'nose': (167, 101), 'mouth_left': (163, 104), 'mouth_right': (169, 105)}}
# {'box': [552, 106, 12, 16], 'confidence': 0.9999687075614929, 'keypoints': {'left_eye': (555, 113), 'right_eye': (562, 113), 'nose': (558, 117), 'mouth_left': (556, 119), 'mouth_right': (561, 119)}}
# {'box': [115, 173, 17, 19], 'confidence': 0.9999552369117737, 'keypoints': {'left_eye': (121, 178), 'right_eye': (129, 178), 'nose': (125, 183), 'mouth_left': (121, 187), 'mouth_right': (129, 187)}}
# {'box': [336, 155, 14, 19], 'confidence': 0.9999521374702454, 'keypoints': {'left_eye': (339, 164), 'right_eye': (346, 162), 'nose': (343, 167), 'mouth_left': (341, 171), 'mouth_right': (347, 169)}}
# ...

# %%
from matplotlib import pyplot as plt

# %%
from mtcnn import MTCNN

# %%
pixel=plt.imread(url)

# %%
detector=MTCNN()
faces=detector.detect_faces(pixel)
# Out:
# ...
# 4/4 [==============================] - 1s 67ms/step

# %%
plt.imshow(pixel)

# %%
url='/content/khangia.jpg'
pixels=plt.imread(url)
detector=MTCNN()
face=detector.detect_faces(pixels)
plt.imshow(pixels)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
plt.show()
# Out:
# ...
# 35/35 [==============================] - 2s 51ms/step

# %%
url='/content/khangia.jpg'
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(pixels)
ax=plt.gca()
for face in faces:
      x,y,width,height=face['box'] 
      rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
      ax.add_patch(rect)
for key,value in face ['keypoints'].items():
   dot=plt.Circle(value,radius=2,color='red')
   ax.add_patch(dot)
plt.show()
# Out:
# ...
# 35/35 [==============================] - 2s 54ms/step

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN

# %%
from matplotlib import pyplot as plt
from mtcnn import MTCNN
def draw_faces(filename, result_list):
          data = plt.imread(filename)
          for i in range(len(result_list)):
            x1, y1, width, height = result_list[i]['box']
            x2, y2 = x1 + width, y1 + height
            plt.subplot(1, len(result_list), i+1)
            plt.axis('off')
            plt.imshow(data[y1:y2, x1:x2])
plt.show
filename = 'AVU.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_faces(filename,faces)
# Out:
# ...
# 4/4 [==============================] - 0s 44ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = 'PIN.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
# Out:
# ...
# 1/1 [==============================] - 1s 1s/step

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG19(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)

img_path = 'caoco.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

block4_pool_features = model.predict(x)
# Out:
# ...
# 1/1 [==============================] - 1s 878ms/step
